# %% [markdown]
# # Proyecto
# ## Física Computacional
# ## Integrantes:
# ### Carlos Sierra Evelin Ameyalli
# $Amee \heartsuit Carlos$ 🐞🐝🦊🐺🌻💀👻
# ### Hernández Ramos Sandra
# $Sandii\hbar ers^{\heartsuit}$ 🦆🌵🌹🥀🌿🍀🌺🌷
#
#
#
# ## Julia 🔴🟢🟣

# %%
using Plots
using DataFrames
using LaTeXStrings
using DifferentialEquations
using BenchmarkTools
# Out:
# ┌ Info: Precompiling DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0]
# └ @ Base loading.jl:1278
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DataFrames [a93c6f00-e57d-5684-b7b6-d8193f3e46c0].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling PrettyTables [08abe8d2-0d0c-5749-adfa-8a2ac140af0d]
# └ @ Base loading.jl:1278
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing PrettyTables [08abe8d2-0d0c-5749-adfa-8a2ac140af0d].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# └ @ Base loading.jl:1278
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e]
# └ @ Base loading.jl:1278
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling NonlinearSolve [8913a72c-1f9b-4ce2-8d82-65094dcecaec]
# └ @ Base loading.jl:1278
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing NonlinearSolve [8913a72c-1f9b-4ce2-8d82-65094dcecaec].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling SciMLBase [0bca4576-84f4-4d90-8ffe-ffa030f20462]
# └ @ Base loading.jl:1278
# ┌ Warning: Module Tables with build ID 322583904643962 is missing from the cache.
# │ This may mean Tables [bd369af6-aec1-5ad0-b16a-f7cc5008161c] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing SciMLBase [0bca4576-84f4-4d90-8ffe-ffa030f20462].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling DiffEqNoiseProcess [77a26b50-5914-5dd7-bc55-306e6241c503]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DiffEqNoiseProcess [77a26b50-5914-5dd7-bc55-306e6241c503].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling SteadyStateDiffEq [9672c7b4-1e72-59bd-8a11-6ac3964bc41f]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing SteadyStateDiffEq [9672c7b4-1e72-59bd-8a11-6ac3964bc41f].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling DiffEqCallbacks [459566f4-90b8-5000-8ac3-15dfb0a30def]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DiffEqCallbacks [459566f4-90b8-5000-8ac3-15dfb0a30def].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling StochasticDiffEq [789caeaf-c7a9-5a7d-9973-96adeb23e2a0]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing StochasticDiffEq [789caeaf-c7a9-5a7d-9973-96adeb23e2a0].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling DiffEqJump [c894b116-72e5-5b58-be3c-e6d8d4ac2b12]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DiffEqJump [c894b116-72e5-5b58-be3c-e6d8d4ac2b12].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling BoundaryValueDiffEq [764a87c0-6b3e-53db-9096-fe964310641d]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing BoundaryValueDiffEq [764a87c0-6b3e-53db-9096-fe964310641d].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling Sundials [c3572dad-4567-51f8-b174-8c6c989267f4]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing Sundials [c3572dad-4567-51f8-b174-8c6c989267f4].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling DelayDiffEq [bcd4f6db-9728-5f36-b5f7-82caef46ccdb]
# └ @ Base loading.jl:1278
# ┌ Warning: Module OrdinaryDiffEq with build ID 2660874511988 is missing from the cache.
# │ This may mean OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DelayDiffEq [bcd4f6db-9728-5f36-b5f7-82caef46ccdb].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling DiffEqFinancial [5a0ffddc-d203-54b0-88ba-2c03c0fc2e67]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DiffEqFinancial [5a0ffddc-d203-54b0-88ba-2c03c0fc2e67].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling MultiScaleArrays [f9640e96-87f6-5992-9c3b-0743c6a49ffa]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing MultiScaleArrays [f9640e96-87f6-5992-9c3b-0743c6a49ffa].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling DiffEqPhysics [055956cb-9e8b-5191-98cc-73ae4a59e68a]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing DiffEqPhysics [055956cb-9e8b-5191-98cc-73ae4a59e68a].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling ParameterizedFunctions [65888b18-ceab-5e60-b2b9-181511a3b968]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing ParameterizedFunctions [65888b18-ceab-5e60-b2b9-181511a3b968].
# └ @ Base loading.jl:1034
# ┌ Info: Precompiling ModelingToolkit [961ee093-0014-501f-94e3-6117800e7a78]
# └ @ Base loading.jl:1278
# ┌ Warning: Module DiffEqBase with build ID 1930641838221 is missing from the cache.
# │ This may mean DiffEqBase [2b5f629d-d688-5b77-993f-72d75c75574e] does not support precompilation but is imported by a module that does.
# └ @ Base loading.jl:1017
# ┌ Info: Skipping precompilation since __precompile__(false). Importing ModelingToolkit [961ee093-0014-501f-94e3-6117800e7a78].
# └ @ Base loading.jl:1034

# %% [markdown]
# ## <span style="color:magenta">Plateamiento del problema<span>

# %% [markdown]
# Considera una partıcula de masa $m$ que se encuentra en el extremo de una vara de longitud $l$ de masa despreciable.
# La partícula es libre de columpiarse en cualquier dirección bajo la acción de la gravedad. Como la partícula está
# contrenida a moverse en la superficie de una esfera.

# %% [markdown]
# Tenemos el siguiente esquema

# %% [markdown]
# <img src="Problema 4 examen.png" width="400" height="400" alt="Esquema del problema planteado">

# %% [markdown]
# Vemos que este sistema es el mismo de un péndulo esférico y bajo ciertas condiciones se transforma en un péndulo simple.

# %% [markdown]
# ## <span style="color:magenta">Objetivo<span>

# %% [markdown]
# Analizar el problema del péndulo simple y péndulo esférico con herramientas aprendidas a lo largo del curso de Física Computacional.

# %% [markdown]
# ## <span style="color:magenta">Introducción del problema<span>

# %% [markdown]
# El péndulo esférico no es más que el movimiento de una partícula sobre una superficie esférica. De acuerdo al planteamiento del problema tenemos que la partícula de masa $m$ está sujeta a una vara de radio $l$ y masa despreciable. Para facilitarnos el trabajo vamos a usar coordenadas esféricas en la resolución del problema $(r,\phi,\theta)$
#
# A continuación obtendremos las ecuaciones de movimiento y todo lo necesario para desarrollar la parte de programación.

# %% [markdown]
# ## <span style="color:magenta">Desarrollo del problema<span>

# %% [markdown]
# Usando las coordenadas esféricas:

# %% [markdown]
# <img src="P4_2.png" width="400" height="400" alt="Esquema del problema planteado">
# Figura 2. Coordenadas esféricas en el problema

# %% [markdown]
# $x=rsen\theta cos\varphi$
#
# $y=rsen\theta sen \varphi$
#
# $z=rcos\theta$
#
# Ahora si consideramos $\vec{r}$ como como la longitud de la vara $l$ podemos reescribir las ecuaciones anteriores como:
#
# $x=lsen\theta cos\varphi$
#
# $y=lsen\theta sen \varphi$
#
# $z=lcos\theta$
#
# Podemos obtener las velocidades de cada componente si derivamos con respecto al tiempo:
#
# $\frac{dx}{dt}=l cos \theta \frac{d\theta}{dt}-lsen\theta sen \varphi\frac{d\varphi}{dt}$
#
# $\frac{dy}{dt}=l cos \theta \frac{d\theta}{dt} sen \varphi + l sen \theta cos \varphi \frac{d\varphi}{dt}$
#
# $\frac{dx}{dt}=-l sen \theta \frac{d\theta}{dt}$

# %% [markdown]
# Para poder obtener las ecuaciones de movimiento de la masa sostenida en el péndulo esférico, debemos obtener su lagrangiana. Recordemos que lagrangiana esta definida como la diferencia entre la energía cinetica y la energía potencial, es decir:
# $$L=T-V$$
# Entonces obtendremos la energía cinética $T$:
# La energía cinética es:
# $$T=\frac{1}{2}mv^{2}$$
# pero en este caso la velocidad $v$ la podemos expresar como una suma de sus componentes:
# $$v^{2}=\left(\frac{dx}{dt}\right)^{2}+\left(\frac{dy}{dt}\right)^{2}+\left(\frac{dz}{dt}\right)^{2}$$
# Ahora sustituyendo $v^{2}$ en $T$ obtenemos:
# $$T=\frac{1}{2}m\left(\left(\frac{dx}{dt}\right)^{2}+\left(\frac{dy}{dt}\right)^{2}+\left(\frac{dz}{dt}\right)^{2}\right)$$

# %% [markdown]
# Ahora si sustituimos los valores de $\frac{dx}{dt}$,$\frac{dy}{dt}$ y $\frac{dz}{dt}$ en $T$ tenemos:
# $$T=\frac{1}{2}m\left(\left(l cos \theta \frac{d\theta}{dt}-lsen\theta sen \varphi\frac{d\varphi}{dt}\right)^{2}+\left(l cos \theta \frac{d\theta}{dt} sen \varphi + l sen \theta cos \varphi \frac{d\varphi}{dt}\right)^{2}+\left(-l sen \theta \frac{d\theta}{dt}\right)^{2}\right)$$

# %% [markdown]
# por conveniencia $\dot{\theta}=\frac{d\theta}{dt}$ y $\dot{\varphi}=\frac{d\varphi}{dt}$

# %% [markdown]
# $$T=\frac{1}{2}m\left(\left(l cos \theta \dot{\theta}-lsen\theta sen \varphi\dot{\varphi}\right)^{2}+\left(l cos \theta \dot{\theta} sen \varphi + l sen \theta cos \varphi \dot{\varphi}\right)^{2}+\left(-l sen \theta \dot{\theta}\right)^{2}\right)$$

# %% [markdown]
# Desarrollando tenemos:
# \begin{equation}
# \begin{aligned}
# T&=\frac{1}{2}m\left(\left(l cos\theta \dot{\theta}-l sen\theta sen\varphi\dot{\varphi}\right)^{2}+\left(l cos\theta \dot{\theta} sen\varphi + l sen\theta cos\varphi \dot{\varphi}\right)^{2}+\left(-l sen\theta \dot{\theta}\right)^{2}\right)\\
# &=\frac{1}{2}m\left(l^{2}cos^{2}\theta\dot{\theta}^{2}cos^{2}\varphi+l^{2}sen^{2}\theta sen^{2} \varphi\dot{\varphi}^{2}-2l^{2}cos\theta sen\theta sen\varphi cos\varphi \dot{\theta} \dot{\varphi}+l^{2}cos^{2}\theta\dot{\theta}^{2} sen^{2}\varphi+l^{2} sen^{2}\theta cos^{2}\varphi \dot{\varphi}^{2}+2l^{2}cos\theta sen\theta sen\varphi cos\varphi \dot{\theta} \dot{\varphi}+l^{2}sen^{2}\theta \dot{\theta}\right)\\
# &=\frac{1}{2}m\left(l^{2} cos^{2}\theta \dot{\theta}^{2} cos^{2}\varphi+l^{2}sen^{2}\theta sen^{2}\varphi \dot{\varphi}^{2} + l^{2} cos^{2}\theta + l^{2} cos^{2}\theta \dot{\theta}^{2} sen^{2}\varphi + l^{2} sen^{2}\theta cos^{2}\varphi \dot{\varphi}^{2} + l^{2} sen^{2}\theta \dot{\theta}^{2}\right)\\
# &=\frac{1}{2}m l^{2}\left(cos^{2}\theta \dot{\theta}^{2} cos^{2}\varphi + sen^{2}\theta sen^{2}\varphi \dot{\varphi}^{2} + cos^{2}\theta \dot{\theta}^{2} sen^{2}\varphi + sen^{2}\theta cos^{2}\varphi \dot{\varphi}^{2} + sen^{2}\theta \dot{\theta}^{2} \right)\\
# &=\frac{1}{2}m l^{2}\left(\dot{\theta}^{2}\left(cos^{2}\theta cos^{2}\varphi+cos^{2}\theta sen^{2}\varphi + sen^{2}\theta \right)+\dot{\varphi}^{2}\left(sen^{2}\theta sen^{2}\varphi + sen^{2}\theta cos^{2}\varphi\right)\right)\\
# &=\frac{1}{2}m l^{2}\left(\dot{\theta}^{2}\left(cos^{2}\theta \left(cos^{2}\varphi + sen^{2}\varphi \right) + sen^{2}\theta \right)+\dot{\varphi}^{2}\left(sen^{2}\theta\left(sen^{2}\varphi + cos^{2}\varphi\right)\right)\right)\\
# &=\frac{1}{2}m l^{2}\left(\dot{\theta}^{2}\left(cos^{2}\theta  + sen^{2}\theta \right)+\dot{\varphi}^{2}sen^{2}\theta\right)\\
# &=\frac{1}{2}ml^{2}\left(\dot{\theta}^{2}+\dot{\varphi}^{2}sen^{2}\theta\right)
# \end{aligned}
# \end{equation}
#
# Entonces tenemos a la energía cinética como:
# $$T=\frac{1}{2}ml^{2}\left(\dot{\theta}^{2}+\dot{\varphi}^{2}sen^{2}\theta\right)$$

# %% [markdown]
# Ahora obtendremos la energía potencial $V$:
# La energía potencial esta dada por $V=-mgz$ usando $z=l cos\theta$:
# $$V=-mglcos\theta$$

# %% [markdown]
# Entonces la Lagrangia **$L=T-V$** la podemos reescribir sustituyendo $T$ y $V$ que ya obtuvimos:
# $$L=\frac{1}{2}ml^{2}\left(\dot{\theta}^{2}+\dot{\varphi}^{2}sen^{2}\theta\right)+mglcos\theta$$

# %% [markdown]
# Apartir de la Lagrangiana podemos obtener las ecuaciones de movimiento:

# %% [markdown]
# La primer ecuación de movimiento es:
# $$\frac{d}{dt}=\left(\frac{\partial L}{\partial \dot{\theta}}\right)-\frac{\partial L}{\partial \theta}=0$$
# Sustituyendo y resolviendo tenemos:
# $$
# l\frac{d^{2}\theta}{dt^{2}}-l sen\theta cos\theta \left(\frac{d\varphi}{dt}\right)^{2}+g sen\theta=0\quad.....(1)
# $$

# %% [markdown]
# Y la segunda ecuación de movimiento es:
# $$\frac{d}{dt}=\left(\frac{\partial L}{\partial \dot{\varphi}}\right)-\frac{\partial L}{\partial \varphi}=0$$
# Sustituyendo y resolviendo tenemos:
# $$\frac{d}{dt}\left(m l^{2} sen^{2}\theta \frac{d\varphi}{d\theta}\right)=0 \quad.....(2)$$

# %% [markdown]
# De las ecuaciones (1) y (2) podemos empezar a definir nuestro sistema de ecuaciones para realizar una función
#
# De la ecuación:
#
# $\frac{d^2\theta}{dt^2}-(\frac{d\varphi}{dt})^2cos\theta\sin\theta+\frac{g}{l}sin\theta$
#
# Veámosla como:
#
# $\ddot{\theta}=\dot{\varphi}^2cos\theta sin\theta-\frac{g}{l}sin\theta$
#
# Y de la ecuación:
#
# $\frac{d^2\varphi}{dt^2}+2\frac{d\theta}{dt}\frac{d\varphi}{dt}cot\theta=0$
#
# La reescribimos como:
#
# $\ddot{\varphi}=-2\dot{\theta}\dot{\varphi}cot\theta$
#
# Entonces obtenemos el siguiente sistema de ecuaciones:
#
# $\frac{d}{dt}\dot{\theta}=\dot{\varphi}^2cos\theta sin\theta-\frac{g}{l}sin\theta$
#
# $\frac{d}{dt}\dot{\varphi}=-2\dot{\theta}\dot{\varphi}cot\theta$
#
# $\frac{d}{dt}\theta=\dot{\theta}$
#
# $\frac{d}{dt}\varphi=\dot{\varphi}$

# %%
# Creo que no usamos esta, así que podríamos borrarla
function raiz_bf(funcion,intervalo,error=1e-4)
    raiz = 0.5*(intervalo[1]+intervalo[2])
    iteracion = 0
    while abs(intervalo[2]-intervalo[1]) > error
        f_izq , f_med = funcion(intervalo[1]) , funcion(raiz)
        if f_izq*f_med < 0
            intervalo[2] = raiz
        else
            intervalo[1] = raiz
        end
        raiz = 0.5*(intervalo[1]+intervalo[2])
        iteracion += 1
    end
    return raiz,iteracion
end
# Out:
# raiz_bf (generic function with 2 methods)

# %%
# Con las ecuaciones que se dedujeron hacemos la función del péndulo esférico
function pendulo_esferico(dx,x,p,t) 
    l=1
    g=9.8
    vtheta=x[3]
    vphi=x[4]
    dvtheta=x[4]^2*cos(x[1])*sin(x[1])-(g/l)*sin(x[1])
    dvphi=-2*x[3]*x[4]*1/tan(x[1])
    return [vtheta,vphi,dvtheta,dvphi]
end
# Out:
# pendulo_esf (generic function with 1 method)

# %%
p_ini = [1.0,0.0] # punto inicial 
t = (0.0,2π) # intervalo de integración
prob = ODEProblem(pendulo_esferico,p_ini,t) # generacion del problema EDO
sol_DE = solve(prob) # generar la solucion del problema

# %%
plot(title="Espacio Fase con DifferentialEquations",xlabel=L"\theta (t)",ylabel=L"v_{\theta}(t)")
plot!(sol_DE[1,:],sol_DE[2,:],label="DiffEq",lw=2) # solucion con segmentos
plot!(sol_DE,vars=(1,2),label="DiffEq interpolado",lw=2) # solucion con interpolación
plot!(aspect_ratio=:equal,legend=(0.5,0.5))

# %%
function RK_2(edo,x_ini,t)
    sol = zeros( length(t) , length(x_ini) )
    sol[1,:] .= x_ini
    δ = t[2]-t[1]
    for i in 1:length(t)-1
        k1 = sol[i,:] .+ 0.5*δ .*edo(sol[i,:],t[i])
        sol[i+1,:] .= sol[i,:] .+ δ*edo(k1,t[i]+0.5*δ)
    end
    return sol
end

function RK_4(edo,x_ini,t)
    sol = zeros( length(t) , length(x_ini) )
    sol[1,:] .= x_ini
    δ = t[2]-t[1]
    for i in 1:length(t)-1
        k1 = edo(sol[i,:],t[i])
        k2 = edo(sol[i,:] .+ 0.5*δ.*k1 , t[i] + 0.5*δ)
        k3 = edo(sol[i,:] .+ 0.5*δ.*k2 , t[i] + 0.5*δ)
        k4 = edo(sol[i,:] .+ δ.*k2 , t[i] + δ)
        sol[i+1,:] .= sol[i,:] .+ (δ/6.0).*(k1 .+ 2.0.*k2 .+ 2.0.*k3 .+ k4)
    end
    return sol
end
# Out:
# RK_4 (generic function with 1 method)

# %%
# Esta no funcionó, igual deberíamos quitarla
plot(title="Espacio Fase",xlabel=L"\theta(t)",ylabel=L"v_{\theta}(t)")
tiempo = collect(0:0.05:5π)
th_ini_s = collect(0.1:0.25:π-0.1)
for th_ini in th_ini_s
    sol_num = RK_2(pendulo_esferico,[th_ini,0],tiempo)
    plot!(sol_num[:,1],sol_num[:,2])
end
plot!(legend=false)
# Out:
# MethodError: no method matching pendulo_esf(::Array{Float64,1}, ::Float64)
# Closest candidates are:
#   pendulo_esf(::Any, ::Any, !Matched::Any, !Matched::Any) at In[13]:2
#
# Stacktrace:
#  [1] RK_2(::typeof(pendulo_esf), ::Array{Float64,1}, ::Array{Float64,1}) at .\In[14]:6
#  [2] top-level scope at .\In[15]:5
#  [3] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
# Esta igual hay que quitarla
p_ini = [1.0,0.0] # punto inicial 
t = (0.0,2π) # intervalo de integración
prob = ODEProblem(pendulo_esf,p_ini,t) # generacion del problema EDO
sol_DE = solve(prob) # generar la solucion del problema

sol_RK2 = RK_2(pendulo_esferico,p_ini,tiempo)
sol_RK4 = RK_4(pendulo_esfeerico,p_ini,tiempo);
# Out:
# BoundsError: attempt to access 2-element Array{Float64,1} at index [3]
#
# Stacktrace:
#  [1] getindex at .\array.jl:809 [inlined]
#  [2] pendulo_esf(::Array{Float64,1}, ::Array{Float64,1}, ::SciMLBase.NullParameters, ::Float64) at .\In[13]:5
#  [3] ODEFunction at C:\Users\Carlos\.julia\packages\SciMLBase\cjif9\src\scimlfunctions.jl:300 [inlined]
#  [4] initialize!(::OrdinaryDiffEq.ODEIntegrator{CompositeAlgorithm{Tuple{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType}},OrdinaryDiffEq.AutoSwitchCache{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},true,Array{Float64,1},Nothing,Float64,SciMLBase.NullParameters,Float64,Float64,Float64,Array{Array{Float64,1},1},OrdinaryDiffEq.ODECompositeSolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,SciMLBase.NullParameters,ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},SciMLBase.StandardODEProblem},CompositeAlgorithm{Tuple{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType}},OrdinaryDiffEq.AutoSwitchCache{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},OrdinaryDiffEq.CompositeInterpolationData{ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},OrdinaryDiffEq.Rosenbrock23Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rosenbrock23Tableau{Float64},SciMLBase.TimeGradientWrapper{ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Array{Float64,1},SciMLBase.NullParameters},SciMLBase.UJacobianWrapper{ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Float64,SciMLBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward}(),Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Float64,Val{:forward}(),Float64,Val{true}()}}},OrdinaryDiffEq.AutoSwitchCache{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}}},DiffEqBase.DEStats},ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},OrdinaryDiffEq.Rosenbrock23Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rosenbrock23Tableau{Float64},SciMLBase.TimeGradientWrapper{ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Array{Float64,1},SciMLBase.NullParameters},SciMLBase.UJacobianWrapper{ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Float64,SciMLBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward}(),Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Float64,Val{:forward}(),F ...
#  [5] initialize!(::OrdinaryDiffEq.ODEIntegrator{CompositeAlgorithm{Tuple{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType}},OrdinaryDiffEq.AutoSwitchCache{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},true,Array{Float64,1},Nothing,Float64,SciMLBase.NullParameters,Float64,Float64,Float64,Array{Array{Float64,1},1},OrdinaryDiffEq.ODECompositeSolution{Float64,2,Array{Array{Float64,1},1},Nothing,Nothing,Array{Float64,1},Array{Array{Array{Float64,1},1},1},ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,SciMLBase.NullParameters,ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},SciMLBase.StandardODEProblem},CompositeAlgorithm{Tuple{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType}},OrdinaryDiffEq.AutoSwitchCache{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}},OrdinaryDiffEq.CompositeInterpolationData{ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Array{Array{Float64,1},1},Array{Float64,1},Array{Array{Array{Float64,1},1},1},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},OrdinaryDiffEq.Rosenbrock23Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rosenbrock23Tableau{Float64},SciMLBase.TimeGradientWrapper{ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Array{Float64,1},SciMLBase.NullParameters},SciMLBase.UJacobianWrapper{ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Float64,SciMLBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward}(),Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Float64,Val{:forward}(),Float64,Val{true}()}}},OrdinaryDiffEq.AutoSwitchCache{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}}},DiffEqBase.DEStats},ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},OrdinaryDiffEq.CompositeCache{Tuple{OrdinaryDiffEq.Tsit5Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},OrdinaryDiffEq.Tsit5ConstantCache{Float64,Float64}},OrdinaryDiffEq.Rosenbrock23Cache{Array{Float64,1},Array{Float64,1},Array{Float64,1},Array{Float64,2},Array{Float64,2},OrdinaryDiffEq.Rosenbrock23Tableau{Float64},SciMLBase.TimeGradientWrapper{ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Array{Float64,1},SciMLBase.NullParameters},SciMLBase.UJacobianWrapper{ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Float64,SciMLBase.NullParameters},DefaultLinSolve,FiniteDiff.JacobianCache{Array{Float64,1},Array{Float64,1},Array{Float64,1},UnitRange{Int64},Nothing,Val{:forward}(),Float64},FiniteDiff.GradientCache{Nothing,Array{Float64,1},Array{Float64,1},Float64,Val{:forward}(),F ...
#  [6] __init(::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,SciMLBase.NullParameters,ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},SciMLBase.StandardODEProblem}, ::CompositeAlgorithm{Tuple{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType}},AutoSwitch{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}}, ::Tuple{}, ::Tuple{}, ::Tuple{}, ::Type{Val{true}}; saveat::Tuple{}, tstops::Tuple{}, d_discontinuities::Tuple{}, save_idxs::Nothing, save_everystep::Bool, save_on::Bool, save_start::Bool, save_end::Bool, callback::Nothing, dense::Bool, calck::Bool, dt::Float64, dtmin::Nothing, dtmax::Float64, force_dtmin::Bool, adaptive::Bool, gamma::Rational{Int64}, abstol::Nothing, reltol::Nothing, qmin::Rational{Int64}, qmax::Int64, qsteady_min::Int64, qsteady_max::Int64, qoldinit::Rational{Int64}, fullnormalize::Bool, failfactor::Int64, beta1::Nothing, beta2::Nothing, maxiters::Int64, internalnorm::typeof(DiffEqBase.ODE_DEFAULT_NORM), internalopnorm::typeof(LinearAlgebra.opnorm), isoutofdomain::typeof(DiffEqBase.ODE_DEFAULT_ISOUTOFDOMAIN), unstable_check::typeof(DiffEqBase.ODE_DEFAULT_UNSTABLE_CHECK), verbose::Bool, timeseries_errors::Bool, dense_errors::Bool, advance_to_tstop::Bool, stop_at_next_tstop::Bool, initialize_save::Bool, progress::Bool, progress_steps::Int64, progress_name::String, progress_message::typeof(DiffEqBase.ODE_DEFAULT_PROG_MESSAGE), userdata::Nothing, allow_extrapolation::Bool, initialize_integrator::Bool, alias_u0::Bool, alias_du0::Bool, initializealg::OrdinaryDiffEq.DefaultInit, kwargs::Base.Iterators.Pairs{Symbol,Bool,Tuple{Symbol,Symbol},NamedTuple{(:default_set, :second_time),Tuple{Bool,Bool}}}) at C:\Users\Carlos\.julia\packages\OrdinaryDiffEq\ZgbOP\src\solve.jl:425
#  [7] __solve(::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,SciMLBase.NullParameters,ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},SciMLBase.StandardODEProblem}, ::CompositeAlgorithm{Tuple{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType}},AutoSwitch{Tsit5,Rosenbrock23{0,false,DefaultLinSolve,DataType},Rational{Int64},Int64}}; kwargs::Base.Iterators.Pairs{Symbol,Bool,Tuple{Symbol,Symbol},NamedTuple{(:default_set, :second_time),Tuple{Bool,Bool}}}) at C:\Users\Carlos\.julia\packages\OrdinaryDiffEq\ZgbOP\src\solve.jl:4
#  [8] __solve(::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,SciMLBase.NullParameters,ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},SciMLBase.StandardODEProblem}, ::Nothing; default_set::Bool, kwargs::Base.Iterators.Pairs{Symbol,Bool,Tuple{Symbol},NamedTuple{(:second_time,),Tuple{Bool}}}) at C:\Users\Carlos\.julia\packages\DifferentialEquations\HSWeG\src\default_solve.jl:7
#  [9] #__solve#70 at C:\Users\Carlos\.julia\packages\DiffEqBase\uRCBr\src\solve.jl:235 [inlined]
#  [10] __solve at C:\Users\Carlos\.julia\packages\DiffEqBase\uRCBr\src\solve.jl:222 [inlined]
#  [11] #solve_call#56 at C:\Users\Carlos\.julia\packages\DiffEqBase\uRCBr\src\solve.jl:61 [inlined]
#  [12] solve_call at C:\Users\Carlos\.julia\packages\DiffEqBase\uRCBr\src\solve.jl:48 [inlined]
#  [13] #solve_up#58 at C:\Users\Carlos\.julia\packages\DiffEqBase\uRCBr\src\solve.jl:85 [inlined]
#  [14] solve_up at C:\Users\Carlos\.julia\packages\DiffEqBase\uRCBr\src\solve.jl:75 [inlined]
#  [15] #solve#57 at C:\Users\Carlos\.julia\packages\DiffEqBase\uRCBr\src\solve.jl:70 [inlined]
#  [16] solve(::ODEProblem{Array{Float64,1},Tuple{Float64,Float64},true,SciMLBase.NullParameters,ODEFunction{true,typeof(pendulo_esf),LinearAlgebra.UniformScaling{Bool},Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,Nothing,typeof(SciMLBase.DEFAULT_OBSERVED),Nothing},Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}},SciMLBase.StandardODEProblem}) at C:\Users\Carlos\.julia\packages\DiffEqBase\uRCBr\src\solve.jl:68
#  [17] top-level scope at In[16]:4
#  [18] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %%
# Igual quitamos esta
plot(title="Comparación entre diferentes integradores",xlabel=L"\theta (t)",ylabel=L"v_{\theta}(t)")
plot!(sol_DE[1,:],sol_DE[2,:],label="DiffEq",lw=2)
plot!(sol_RK2[:,1],sol_RK2[:,2],label="RK 2",lw=2)
plot!(sol_RK4[:,1],sol_RK4[:,2],label="RK 4",lw=2)
# Out:
# UndefVarError: sol_DE not defined
#
# Stacktrace:
#  [1] top-level scope at In[17]:2
#  [2] include_string(::Function, ::Module, ::String, ::String) at .\loading.jl:1091

# %% [markdown]
# ### <span style="color:green">Energía Potencial<span>

# %% [markdown]
# Como la lagrangiana $L$ no depende de $varphi$, de la segunda ecuación de movimiento obtenemos una cantidad $h$ que se conserva.
# $$sen^{2}\theta \frac{d\varphi}{dt}=h \quad.....(2.1)$$
#
# está cantidad esta relacionada con el componente en $z$ del momento angular $L$:
# $$\vec{L}=\vec{r}\times m\vec{v}$$
#
# $$L_{z}=m\left(x\frac{dy}{dt}-y\frac{dx}{dt}\right)=ml^{2}sen^{2}\theta\frac{d\varphi}{dt}$$

# %% [markdown]
# Ahora recordemos que la frecuencia está dada por:
# $$\omega_{0}^{2}=\frac{g}{l}$$
# usando esto podemos reescribir la ecuación (1) de movimiento como:
# $$\frac{d^{2}\theta}{dt^{2}}-\frac{h^{2}}{sen^{3}\theta}cos\theta+\omega_{0}^{2}sen\theta=0\quad......(1.1)$$

# %% [markdown]
# Derivando esto también tenemos una cantidad que se conserva:
# $$
# \frac{d}{dt}\left(\frac{1}{2}\left(\frac{d\theta}{dt}\right)^{2}+\frac{h^{2}}{2sen^{2}\theta}-\omega_{0}^{2}cos\theta\right)=0
# $$

# %% [markdown]
# La conservación de la energía $\varepsilon$ se escribe como:
# $$
# \frac{1}{2}\left(\frac{d\theta}{dt}\right)^{2}+\frac{h^{2}}{2sen^{2}\theta}-\omega_{0}^{2}cos\theta=\varepsilon
# $$

# %% [markdown]
# Donde $V(\theta)$ es la energía potencial efectiva
# $$
# V(\theta)=\frac{h^{2}}{2sen^{2}\theta}-\omega_{0}^{2}cos\theta
# $$

# %%
l=1
w_0=sqrt(9.8/l)
h2=21.1
V(theta)=(h2/(2*sin(theta)*sin(theta))) - w_0^2*cos(theta)
# Out:
# V (generic function with 1 method)

# %%
x = collect(0.4:0.0002:2.7)
#raiz = raiz_bf(V,[2.0,2.5])
#println("Valor de la raíz: ",raiz[1],"\t Número de iteraciones: ",raiz[2])
#raiz2 = raiz_bf(V,[0.4,0.55])
#println("Valor de la raíz: ",raiz2[1],"\t Número de iteraciones: ",raiz2[2])
plot(x,V,label="V(θ)",title="Energía potencial efectiva",xlabel="θ",ylabel="V(θ)")
#scatter!([raiz[1]],[37.7],label="raíz")
#scatter!([raiz2[1]],[37.7],label="raíz")

# %% [markdown]
# Recordando las ecuaciones (1.1) y (2.1)
# $$
# \frac{d^{2}\theta}{dt^{2}}-\frac{h^{2}}{sen^{3}\theta}cos\theta+\omega_{0}^{2}sen\theta=0$$
#
# $$
# sen^{2}\theta \frac{d\varphi}{dt}=h
# $$

# %% [markdown]
# Si hacemos a $\varphi$ constante entonces tenemos que $\frac{d\varphi}{dt}=0$, lo que implica que $h=0$ por la segunda ecuación, entonces como $h=0$ la primer ecuación nos queda como:$$
# \frac{d^{2}\theta}{dt^{2}}+\omega_{0}^{2}sen\theta=0
# $$
#
# $$
# \rightarrow \frac{d^{2}\theta}{dt^{2}}=-\omega_{0}^{2}sen\theta
# $$
#
# De esto obtenemos el siguiente sistema de ecuaciones diferenciales:
#
# $$
# \frac{d\theta}{dt}=v_{\theta}
# $$
#
# $$
# \frac{dv_{\theta}}{dt}=-\omega_{0}^{2}sen\theta
# $$
#
# Ahora definimos una función donde estará el sistema de ecuaciones diferenciales.

# %%
function pendulo(t_vt,t,w_0 = 1)
    dth = t_vt[2]
    dv_th = -w_0*sin(t_vt[1])
    return [dth,dv_th]
end
# Out:
# pendulo (generic function with 2 methods)

# %%
tiempo = collect(0:0.05:5π)
th_ini_s = collect(0.1:0.25:π-0.1)
for th_ini in th_ini_s
    sol_num = RK_2(pendulo,[th_ini,0],tiempo)
    plot!(sol_num[:,1],sol_num[:,2])
end
plot!(legend=false)

# %%
plot(title="Péndulo en función del tiempo (Runge-Kutta de 2do orden)",xlabel=L"t",ylabel=L"\theta(t)")
tiempo = collect(0:0.01:60π)
sol_num_rk2 = RK_2(pendulo,[0.5,0.0],tiempo)
plot!(tiempo,sol_num_rk2[:,1])
plot!(legend=false)

# %%
p_ini = [1.0,0.0] # definimos punto inicial 
t = (0.0,2π) # intervalo de integración
prob = ODEProblem(pendulo,p_ini,t) # generacion del problema EDO
sol_DE = solve(prob) # generar la solucion del problema
# Out:
# retcode: Success
# Interpolation: automatic order switching interpolation
# t: 23-element Array{Float64,1}:
#  0.0
#  9.999999999999999e-5
#  0.0010999999999999998
#  0.011099999999999997
#  0.060647785517189544
#  0.1512821533295856
#  0.28388881739981636
#  0.46564436040621593
#  0.705341486878873
#  1.0041463368731662
#  1.3587346140244803
#  1.76624257870638
#  2.2391024477515726
#  2.664764165732689
#  3.138620591349519
#  3.5645061035010692
#  4.0299371446410825
#  4.466615819071025
#  4.9031983091339315
#  5.282291051543157
#  5.721485911640595
#  6.08797955215596
#  6.283185307179586
# u: 23-element Array{Array{Float64,1},1}:
#  [1.0, 0.0]
#  [0.9999999999998598, -4.207354924039329e-9]
#  [0.9999999998133338, -5.090899457843701e-7]
#  [0.9999998081963707, -5.183881746539186e-5]
#  [0.9999687153722008, -0.001547517452599068]
#  [0.9995144612448954, -0.009627873362744564]
#  [0.996792596456027, -0.033880296170301104]
#  [0.9858662464328809, -0.0908921777176463]
#  [0.9511013769772932, -0.20662119800467005]
#  [0.8606871336332004, -0.4079245324323987]
#  [0.6654302016978064, -0.6981239345550762]
#  [0.31583782686023615, -0.9981095759637295]
#  [-0.18687992635429224, -1.0512555808896362]
#  [-0.5646897767308413, -0.6514667312854625]
#  [-0.6844318756821363, 0.19081580140365828]
#  [-0.42907841297513505, 0.9734192701228148]
#  [0.12419358273130643, 1.2475033180257746]
#  [0.5544395671381273, 0.5860211557652103]
#  [0.5621612485544709, -0.5706212338930775]
#  [0.18600266549565986, -1.3099787323202108]
#  [-0.38228396520774094, -1.0439241527037004]
#  [-0.5830277859875054, 0.023494286964738764]
#  [-0.5151085963039104, 0.6640830348393221]

# %%
tiempo = collect(range(0,stop=2π,length=length(sol_DE[1,:])))
sol_RK2 = RK_2(pendulo,p_ini,tiempo)
sol_RK4 = RK_4(pendulo,p_ini,tiempo);

# %%
plot(title="Comparación entre diferentes integradores",xlabel=L"\theta (t)",ylabel=L"v_{\theta}(t)")
plot!(sol_DE[1,:],sol_DE[2,:],label="DiffEq",lw=2)
plot!(sol_RK2[:,1],sol_RK2[:,2],label="RK 2",lw=2)
plot!(sol_RK4[:,1],sol_RK4[:,2],label="RK 4",lw=2)
plot!(aspect_ratio=:equal)

# %% [markdown]
# ## <span style="color:magenta">Discusión y conclusión <span>

# %% [markdown]
# Para analizar la función del péndulo notamos que hay dos formas de hacerlo. La primera es tomando las dos ecuaciones que resultan para la segunda derivada de los ángulos y la otra es suponer que uno de estos ángulos es constante y así nos quedamos con una ecuación.
#
# Para la primera definimos nuestra función de péndulo esférico, sin embargo, notamos que al intentar graficar el espacio fase no se obtuvo el resultado esperado y pensamos que se deba a que no logramos definir bien esa función.
#
# En el análisis energético si pudimos obtener una gráfica que nos da el potencial del sistema, aquí si obtuvimos la curva que se esperaba.
#
# En la segunda función de un péndulo simple nuevamente se hizo un análisis energético y obtuvimos una curva similar a la del péndulo esférico.
#
# Cuando se analizó el péndulo en función del tiempo con la función Runge-Kutta de 2do orden pudimos observar que la función tiene comportamiento de oscilador armónico como se espera.
#
# Y al hacer la comparación de diferentes integradores que la solución de Differential Equations se aleja mucho a la que se obtienen con los métodos Runge-Kutta.

# %% [markdown]
# ## <span style="color:magenta">Bibliografía<span>
